# %%
import sqlite3
import pandas as pd

# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (9.7.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (2.0.46)
# Requirement already satisfied: sqlparse in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (0.5.4)
# Requirement already satisfied: six in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\msi\appdata\local\programs\python\python314\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the SpaceX dataset from IBM cloud storage
df = pd.read_csv(
    "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv"
)

# %%
# Create a SQLite database connection
con = sqlite3.connect("my_data1.db")

# %%
# Store the DataFrame as a SQL table for analysis 
df.to_sql("SPACEXTBL", con, if_exists="replace", index=False)
# Out:
# 101

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing_Outcome'],
#       dtype='object')

# %%
# Count the total number of records in the table
pd.read_sql("SELECT COUNT(*) FROM SPACEXTBL", con)
# Out:
#    COUNT(*)
# 0       101

# %%
# Retrieve all unique launch sites used in SpaceX missions
pd.read_sql(
    "SELECT DISTINCT Launch_Site FROM SPACEXTBL",
    con
)
# Out:
#     Launch_Site
# 0   CCAFS LC-40
# 1   VAFB SLC-4E
# 2    KSC LC-39A
# 3  CCAFS SLC-40

# %%
# Find launch sites whose names start with 'CCA'
pd.read_sql(
    "SELECT DISTINCT Launch_Site FROM SPACEXTBL WHERE Launch_Site LIKE 'CCA%'",
    con
)
# Out:
#     Launch_Site
# 0   CCAFS LC-40
# 1  CCAFS SLC-40

# %%
# Calculate the total payload mass carried by boosters launched for NASA (CRS)
pd.read_sql(
    """
    SELECT SUM(PAYLOAD_MASS__KG_) AS total_payload_mass
    FROM SPACEXTBL
    WHERE Customer = 'NASA (CRS)'
    """,
    con
)
# Out:
#    total_payload_mass
# 0               45596

# %%
# This query calculates the average payload mass (in kilograms)
# carried by the Falcon 9 booster version F9 v1.1.
pd.read_sql(
    """
    SELECT AVG(PAYLOAD_MASS__KG_) AS avg_payload_mass
    FROM SPACEXTBL
    WHERE Booster_Version = 'F9 v1.1'
    """,
    con
)
# Out:
#    avg_payload_mass
# 0            2928.4

# %%
# This query finds the earliest date when a booster successfully landed on a ground pad.
pd.read_sql(
    """
    SELECT MIN(Date) AS first_successful_ground_landing
    FROM SPACEXTBL
    WHERE Landing_Outcome = 'Success (ground pad)'
    """,
    con
)
# Out:
#   first_successful_ground_landing
# 0                      2015-12-22

# %%
# This query lists booster versions that successfully landed on a drone ship
# while carrying a payload mass between 4000 and 6000 kg.
pd.read_sql(
    """
    SELECT DISTINCT Booster_Version
    FROM SPACEXTBL
    WHERE Landing_Outcome = 'Success (drone ship)'
      AND PAYLOAD_MASS__KG_ > 4000
      AND PAYLOAD_MASS__KG_ < 6000
    """,
    con
)
# Out:
#   Booster_Version
# 0     F9 FT B1022
# 1     F9 FT B1026
# 2  F9 FT  B1021.2
# 3  F9 FT  B1031.2

# %%
# This query counts the total number of missions for each outcome (success or failure),
# providing an overview of mission performance.
pd.read_sql(
    """
    SELECT Landing_Outcome, COUNT(*) AS total_count
    FROM SPACEXTBL
    GROUP BY Landing_Outcome
    """,
    con
)
# Out:
#            Landing_Outcome  total_count
# 0       Controlled (ocean)            5
# 1                  Failure            3
# 2     Failure (drone ship)            5
# 3      Failure (parachute)            2
# 4               No attempt           21
# 5              No attempt             1
# 6   Precluded (drone ship)            1
# 7                  Success           38
# 8     Success (drone ship)           14
# 9     Success (ground pad)            9
# 10    Uncontrolled (ocean)            2

# %%
# This query groups all landing outcomes into Success or Failure categories
# and counts the total number of missions for each category.

# Normalize the landing outcomes
df['mission_outcome'] = df['Landing_Outcome'].apply(
    lambda x: 'Success' if x is not None and 'Success' in str(x) else 'Failure'
)

# Count
df['mission_outcome'].value_counts()
# Out:
# mission_outcome
# Success    61
# Failure    40
# Name: count, dtype: int64

# %%
# This query lists all booster versions that carried the maximum payload mass
pd.read_sql(
    """
    SELECT Booster_Version
    FROM SPACEXTBL
    WHERE PAYLOAD_MASS__KG_ = (
        SELECT MAX(PAYLOAD_MASS__KG_)
        FROM SPACEXTBL
    )
    """,
    con
)
# Out:
#    Booster_Version
# 0    F9 B5 B1048.4
# 1    F9 B5 B1049.4
# 2    F9 B5 B1051.3
# 3    F9 B5 B1056.4
# 4    F9 B5 B1048.5
# 5    F9 B5 B1051.4
# 6    F9 B5 B1049.5
# 7   F9 B5 B1060.2
# 8   F9 B5 B1058.3
# 9    F9 B5 B1051.6
# 10   F9 B5 B1060.3
# 11  F9 B5 B1049.7

# %%
# This query lists all records from 2015 where the landing outcome failed on a drone ship
pd.read_sql(
    """
    SELECT
        CASE strftime('%m', Date)
            WHEN '01' THEN 'January'
            WHEN '02' THEN 'February'
            WHEN '03' THEN 'March'
            WHEN '04' THEN 'April'
            WHEN '05' THEN 'May'
            WHEN '06' THEN 'June'
            WHEN '07' THEN 'July'
            WHEN '08' THEN 'August'
            WHEN '09' THEN 'September'
            WHEN '10' THEN 'October'
            WHEN '11' THEN 'November'
            WHEN '12' THEN 'December'
        END AS MonthName,
        Landing_Outcome,
        Booster_Version,
        Launch_Site
    FROM SPACEXTBL
    WHERE Landing_Outcome = 'Failure (drone ship)'
      AND strftime('%Y', Date) = '2015';
    """,
    con
)
# Out:
#   MonthName       Landing_Outcome Booster_Version  Launch_Site
# 0   January  Failure (drone ship)   F9 v1.1 B1012  CCAFS LC-40
# 1     April  Failure (drone ship)   F9 v1.1 B1015  CCAFS LC-40

# %%
# This query counts all landing outcomes between 2010-06-04 and 2017-03-20
pd.read_sql(
    """
    SELECT Landing_Outcome, COUNT(*) AS total_count
    FROM SPACEXTBL
    WHERE Date BETWEEN '2010-06-04' AND '2017-03-20'
    GROUP BY Landing_Outcome
    ORDER BY total_count DESC;
    """,
    con
)
# Out:
#           Landing_Outcome  total_count
# 0              No attempt           10
# 1    Success (drone ship)            5
# 2    Failure (drone ship)            5
# 3    Success (ground pad)            3
# 4      Controlled (ocean)            3
# 5    Uncontrolled (ocean)            2
# 6     Failure (parachute)            2
# 7  Precluded (drone ship)            1
